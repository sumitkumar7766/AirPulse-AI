# %% [markdown]
# # AirPulse AI – Pollution Source Attribution Notebook
# ## Chemical Speciation Multi-Class Classification (Traffic, Construction, Industrial, Waste, Residential)

# %% [markdown]
# ### Step 1: Imports & Setup

# %%
import os
import sys
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

print('✅ Imports complete for Pollution Source Attribution!')
# Out:
# ✅ Imports complete for Pollution Source Attribution!

# %% [markdown]
# ### Step 2: Load Speciation Data & Model Training

# %%
sys.path.append(os.path.abspath('../src'))
from train_attribution import train_attribution_model

clf = train_attribution_model()
print(f'🏆 Trained Classifier: {type(clf).__name__}')
# Out:
# ✅ Source attribution classifier model saved (Accuracy: 100.00%) to: /Users/sumitkumar776693/Desktop/Project/Hackathon/ET Hackathon/ml/src/../models/pollution_source_model.pkl
# 🏆 Trained Classifier: RandomForestClassifier

# %% [markdown]
# ### Step 3: Feature Importance Analysis

# %%
feature_names = ['pm25', 'pm10', 'no2', 'so2', 'co']
importances = clf.feature_importances_

plt.figure(figsize=(7, 4))
sns.barplot(x=importances, y=feature_names, color='#2563EB')
plt.title('Pollutant Feature Importance in Source Classification')
plt.show()

# %% [markdown]
# ### Step 4: Real-Time Inference Test

# %%
# Test Traffic Chemical Signature (High NO2 & CO)
sample = np.array([[110.0, 150.0, 85.0, 15.0, 3.5]])
pred_class = clf.predict(sample)[0]
classes = ['Traffic Emissions', 'Construction Dust', 'Industrial Plumes', 'Waste Burning', 'Residential Emissions']
print(f'🔮 Predicted Source: {classes[pred_class]}')
# Out:
# 🔮 Predicted Source: Traffic Emissions
# /Users/sumitkumar776693/Desktop/Project/Hackathon/ET Hackathon/ml/venv/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
